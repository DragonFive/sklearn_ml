# %% [markdown]
# ## mathjax
# ---
# 下面把mathjax安装到本地

# %%
from IPython.external.mathjax import install_mathjax
install_mathjax()
# Out:
# Downloading mathjax source from https://github.com/mathjax/MathJax/archive/2.4.0.tar.gz
# Extracting to /home/dragon/.ipython/nbextensions/mathjax
# 0

# %%
import numpy as np 
from scipy.ndimage import filters
import io
import matplotlib
import matplotlib.image as mpimg
img=np.zeros((300,300))
img[np.random.randint(0,300,1000),np.random.randint(0,300,1000)]=255
img2=filters.gaussian_filter(img,4,order=2)
import io
import matplotlib
import matplotlib.image as mpimg
from IPython import display
buf = io.BytesIO()
matplotlib.image.imsave(buf, img2, cmap="gray")
display.Image(buf.getvalue())

# %% [markdown]
# ##LaTex 演示
# ---
# 下面测试的是Latex表示公式

# %%
from IPython.display import Latex
Latex(r"$\sqrt{x^2+y^2}$")
# Out:
# $\sqrt{x^2+y^2}$

# %% [markdown]
# # sklearn
# ---
# 下面测试使用sklearn
# ## 导入例子数据库
# 一个数据库就像字典类型，数据保存在```.data```成员变量里面，``` .target```保存的是对应到真值

# %%
from sklearn import datasets
iris = datasets.load_iris()
digits=datasets.load_digits()


#iris.target?
#print(iris.data)
print(digits.target)
# Out:
# [0 1 2 ..., 8 9 8]
